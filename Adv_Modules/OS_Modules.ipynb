# %%
pwd
# Out:
# '/home/alexhenri/PythonCourse/Adv_Modules'

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/alexhenri/PythonCourse/Adv_Modules'

# %%
# os.getcwd() works in any python script, pwd works only in jupyter notebook

# %%
f = open('practice.txt', 'w+')

# %%
f.write('This is test string')
# Out:
# 19

# %%
f.close()

# %%
os.listdir()
# Out:
# ['practice.txt', '.ipynb_checkpoints', 'Collections.ipynb', 'OS_Modules.ipynb']

# %%
os.listdir('/home/alexhenri/PythonCourse/')
# Out:
# ['Modules_and_Packages',
#  'Tests',
#  'Milestone_Project_1',
#  '.gitignore',
#  'OOP',
#  'HelloWorld',
#  '.ipynb_checkpoints',
#  'pythonRoadMap.jpeg',
#  'Milestone_Project_2',
#  'README.md',
#  'Basics',
#  '.git',
#  'Milestone_Project_3',
#  'Decorators',
#  'Adv_Modules',
#  'Main_Function',
#  'Complete-Python-3-Bootcamp-master',
#  'Errors_and_Exceptions',
#  'Generators']

# %%
import shutil

# %%
shutil.move('practice.txt', '/home/alexhenri/PythonCourse/') #shift tab to see
# Out:
# '/home/alexhenri/PythonCourse/practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Collections.ipynb', 'OS_Modules.ipynb']

# %%
os.listdir('/home/alexhenri/PythonCourse/')
# Out:
# ['practice.txt',
#  'Modules_and_Packages',
#  'Tests',
#  'Milestone_Project_1',
#  '.gitignore',
#  'OOP',
#  'HelloWorld',
#  '.ipynb_checkpoints',
#  'pythonRoadMap.jpeg',
#  'Milestone_Project_2',
#  'README.md',
#  'Basics',
#  '.git',
#  'Milestone_Project_3',
#  'Decorators',
#  'Adv_Modules',
#  'Main_Function',
#  'Complete-Python-3-Bootcamp-master',
#  'Errors_and_Exceptions',
#  'Generators']

# %%
os.unlink #delete file
# Out:
# <function posix.unlink(path, *, dir_fd=None)>

# %%
os.rmdir # delete folder empty
# Out:
# <function posix.rmdir(path, *, dir_fd=None)>

# %%
shutil.rmtree # remove everything from path
# Out:
# <function shutil.rmtree(path, ignore_errors=False, onerror=None)>

# %%
# Better use send2trash, because i can recover.

# %%
# pip install send2trash
# import send2trash

# %%
import send2trash

# %%
send2trash.send2trash('/home/alexhenri/PythonCourse/practice.txt')

# %%
os.getcwd()
file_path = '/home/alexhenri/PythonCourse/'

# %%
for folder,sub_folders, files in os.walk(file_path):
    print(f'Currently looking at {folder}')
    print('\n')
    print(f'The subfolders are:')
    for sub_fold in sub_folders:
        print(f'\tSubfolder:{sub_fold}')
    print('\n')
    for f in files:
        print(f'\tFile: {f}')
    print('\n')
# Out:
# Currently looking at /home/alexhenri/PythonCourse/
#
#
# The subfolders are:
# 	Subfolder:Modules_and_Packages
# 	Subfolder:Tests
# 	Subfolder:Milestone_Project_1
# 	Subfolder:OOP
# 	Subfolder:HelloWorld
# 	Subfolder:.ipynb_checkpoints
# 	Subfolder:Milestone_Project_2
# 	Subfolder:Basics
# 	Subfolder:.git
# 	Subfolder:Milestone_Project_3
# 	Subfolder:Decorators
# 	Subfolder:Adv_Modules
# 	Subfolder:Main_Function
# 	Subfolder:Complete-Python-3-Bootcamp-master
# 	Subfolder:Errors_and_Exceptions
# 	Subfolder:Generators
#
#
# 	File: .gitignore
# 	File: pythonRoadMap.jpeg
# 	File: README.md
#
#
# Currently looking at /home/alexhenri/PythonCourse/Modules_and_Packages
#
#
# The subfolders are:
# 	Subfolder:__pycache__
# 	Subfolder:MyMainPackage
# 	Subfolder:.idea
#
#
# 	File: main.py
# 	File: mymodule.py
#
#
# Currently looking at /home/alexhenri/PythonCourse/Modules_and_Packages/__pycache__
#
#
# The subfolders are:
#
#
# 	File: mymodule.cpython-36.pyc
#
#
# ...
